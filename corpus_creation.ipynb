# %% [markdown]
# ## Korpuserstellung

# %% [markdown]
# Dieser Code liest vollständig die Datei `thunberg_reisen02_1794.tcf.xml` aus und schreibt den original, sowie den standardisierten Text in eine json-Datei.
#
# Anschließend werden die ausgezeichneten Personen- und Ortsnamen aus `Thunberg_Reisen_2_1794.xml` ausgelesen und in die `reisen02_tcf.json` integriert.

# %%
import xml.etree.ElementTree as ET
import json
import re

# ---------- Schritt 1: Entity-IDs aus zweiter XML lesen ----------
entity_ids = {}
pers_count = 0
place_count = 0

tree_entities = ET.parse('Thunberg_Reisen_2_1794.xml')
root_entities = tree_entities.getroot()

ns_tei = {'tei': 'http://www.tei-c.org/ns/1.0'}  # TEI-XML Namespace

# <persName> Elemente
for pers in root_entities.findall('.//tei:persName', namespaces=ns_tei):
    for w in pers.findall('.//tei:w', namespaces=ns_tei):
        wid = w.get('{http://www.w3.org/XML/1998/namespace}id')
        if wid:
            entity_ids[wid] = 'persName'
            pers_count += 1

# <placeName> Elemente
for place in root_entities.findall('.//tei:placeName', namespaces=ns_tei):
    for w in place.findall('.//tei:w', namespaces=ns_tei):
        wid = w.get('{http://www.w3.org/XML/1998/namespace}id')
        if wid:
            entity_ids[wid] = 'placeName'
            place_count += 1

# ---------- Schritt 2: TCF-Datei einlesen und verarbeiten ----------
tree = ET.parse('thunberg_reisen02_1794.tcf.xml')
root = tree.getroot()

ns = {'tc': 'http://www.dspin.de/data/textcorpus'}

tokens_elem = root.find('.//tc:tokens', namespaces=ns)
sentences_elem = root.find('.//tc:sentences', namespaces=ns)
orthography_elem = root.find('.//tc:orthography', namespaces=ns)

token_map = {}
global_index = 0
for token in tokens_elem.findall('tc:token', namespaces=ns):
    token_id = token.get('ID')
    token_text = token.text
    token_map[token_id] = {
        'text': token_text,
        'global_token_index': global_index
    }
    global_index += 1

corrections_map = {}
if orthography_elem is not None:
    for correction in orthography_elem.findall('tc:correction', namespaces=ns):
        corr_text = correction.text
        corr_token_ids = correction.get('tokenIDs', '').split()
        for tid in corr_token_ids:
            corrections_map[tid] = corr_text

# ---------- Schritt 3: Sätze mit XML-Token-ID und Entitäten versehen ----------
sentences_json = []
matched_pers = 0
matched_place = 0

for i, sentence in enumerate(sentences_elem.findall('tc:sentence', namespaces=ns)):
    token_ids = sentence.get('tokenIDs').split()
    orig_tokens = []
    norm_tokens = []

    for local_id, tid in enumerate(token_ids):
        token_info = token_map.get(tid)
        if not token_info:
            continue
        global_idx = token_info['global_token_index']
        original_text = token_info['text']
        corrected_text = corrections_map.get(tid, original_text)

        xml_token_id = tid  # ← die xml:id, mit der verglichen wird

        entity_type = entity_ids.get(xml_token_id)

        if entity_type == 'persName':
            matched_pers += 1
        elif entity_type == 'placeName':
            matched_place += 1

        orig_token = {
            'token_id': local_id,
            'xml_token_id': xml_token_id,
            'text': original_text,
            'global_token_index': global_idx
        }
        norm_token = {
            'token_id': local_id,
            'xml_token_id': xml_token_id,
            'text': corrected_text,
            'global_token_index': global_idx
        }

        if entity_type:
            orig_token['entity_type'] = entity_type
            norm_token['entity_type'] = entity_type

        orig_tokens.append(orig_token)
        norm_tokens.append(norm_token)

    def clean_spacing(text):
        return re.sub(r'\s+([.,;:!?])', r'\1', text)

    orig_sentence_text = clean_spacing(" ".join(tok["text"] for tok in orig_tokens))
    norm_sentence_text = clean_spacing(" ".join(tok["text"] for tok in norm_tokens))

    sentences_json.append({
        'sentence_id': i,
        'orig_sentence': {
            'text': orig_sentence_text,
            'tokens': orig_tokens
        },
        'norm_sentence': {
            'text': norm_sentence_text,
            'tokens': norm_tokens
        }
    })

# ---------- Schritt 4: JSON schreiben ----------
with open('reisen02_tcf.json', 'w', encoding='utf-8') as f:
    json.dump({'sentences': sentences_json}, f, ensure_ascii=False, indent=2)

# ---------- Schritt 5: Ergebnis ausgeben ----------
print("Fertig! JSON gespeichert als 'reisen02_tcf.json'.")
print(f"Entitäten aus zweiter XML: {pers_count} persName, {place_count} placeName")
print(f"Tatsächlich übertragene Entitäten: {matched_pers} persName, {matched_place} placeName")

# ---------- Schritt 6: Fehlende Entity-IDs ausgeben ----------

# Set aller xml_token_ids, die im JSON vorkommen
json_token_ids = set()

for sentence in sentences_json:
    for token in sentence['orig_sentence']['tokens']:
        if 'xml_token_id' in token:
            json_token_ids.add(token['xml_token_id'])

# Fehlende IDs aus placeName
missing_place_ids = [tid for tid, typ in entity_ids.items()
                     if typ == 'placeName' and tid not in json_token_ids]

# Ausgabe
if missing_place_ids:
    print(f"\nEs wurden {len(missing_place_ids)} placeName-IDs nicht übertragen:")
    for mid in missing_place_ids:
        print(f"  - {mid}'")
else:
    print("\n✅ Alle placeName-IDs wurden erfolgreich übertragen.")
# Out:
# Fertig! JSON gespeichert als 'reisen02_tcf.json'.
# Entitäten aus zweiter XML: 422 persName, 1677 placeName
# Tatsächlich übertragene Entitäten: 422 persName, 1672 placeName
#
# Es wurden 5 placeName-IDs nicht übertragen:
#   - w47b8_1'
#   - w7c71_1'
#   - wb717_1'
#   - w10d79_1'
#   - w14915_1'

# %% [markdown]
# Vier der fünf fehlenden Ortsnamen sind nur scheinbar nicht vorhanden, da ihre IDs mit "_" auf eine Worttrennung verweisen. In der JSON sind die vollständigen Wörter aber letztendlich dennoch korrekt ausgezeichnet worden. Nur die die erste ID wurd aufrund eienr fehlerhaften Auszeichnung nicht korrekt übertragen, was an dieser Stelle aber nicht weiter stören soll.
#
# Das nachstehende Skript prüft noch einmal die Korrektheit der übertragennen Begriffe. Zunächst scheinen etliche Namen Fehlerhaft zu sein, beim näheren Hinsehen handelt es sich aber nur um Normalisierungs-Unterschiede oder weitere Worttrennungen. Letztlich sind in der JSON die richtigen Namen ausgezeichnet.

# %%
import xml.etree.ElementTree as ET
import json

# ---------- XML einlesen ----------
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}
tree = ET.parse("Thunberg_Reisen_2_1794.xml")
root = tree.getroot()

# Alle <w> sammeln, die Teil von persName oder placeName sind
xml_tokens = {}

for tag in ["persName", "placeName"]:
    for ent in root.findall(f".//tei:{tag}", namespaces=NS):
        for w in ent.findall(".//tei:w", namespaces=NS):
            wid = w.get("{http://www.w3.org/XML/1998/namespace}id")
            text = w.text.strip() if w.text else ""
            if wid:
                xml_tokens[wid] = text

# ---------- JSON einlesen ----------
with open("reisen02_tcf.json", encoding="utf-8") as f:
    json_data = json.load(f)

json_tokens = {}

for sentence in json_data["sentences"]:
    for token in sentence["norm_sentence"]["tokens"]:
        wid = token.get("xml_token_id")
        if wid:
            json_tokens[wid] = token["text"]

# ---------- Vergleich ----------
mismatches = []

for wid, xml_text in xml_tokens.items():
    json_text = json_tokens.get(wid)
    if json_text is not None:
        if xml_text != json_text:
            mismatches.append((wid, xml_text, json_text))

# ---------- Ausgabe ----------
print(f"Vergleich abgeschlossen.")
print(f"Verglichene IDs: {len(xml_tokens)}")
print(f"Übereinstimmend: {len(xml_tokens) - len(mismatches)}")
print(f"Nicht übereinstimmend: {len(mismatches)}\n")

if mismatches:
    print("Nicht übereinstimmende Tokens:")
    for wid, xml_text, json_text in mismatches:
        print(f"  - {wid}: XML='{xml_text}' vs. JSON='{json_text}'")
# Out:
# Vergleich abgeschlossen.
# Verglichene IDs: 2099
# Übereinstimmend: 1469
# Nicht übereinstimmend: 630
#
# Nicht übereinstimmende Tokens:
#   - w3d: XML='Chriſtian' vs. JSON='Christian'
#   - w406: XML='Rudenſchoͤld' vs. JSON='Rudenschöld'
#   - w41b: XML='Baͤck' vs. JSON='Bäck'
#   - wec8: XML='Linné' vs. JSON='Linne'
#   - wed2: XML='Lidrén' vs. JSON='Lidren'
#   - wf12: XML='Hornſtedt' vs. JSON='Hornstedt'
#   - wf1f: XML='Caßſtröm' vs. JSON='Caßström'
#   - wf74: XML='Engeſtröm' vs. JSON='Engeström'
#   - wfa5: XML='Borgſtröm' vs. JSON='Borgström'
#   - wfad: XML='Heſſelius' vs. JSON='Hesselius'
#   - wfb5: XML='Berg' vs. JSON='Berg.'
#   - w1002: XML='Gallén' vs. JSON='Gallen'
#   - w1019: XML='Schalén' vs. JSON='Schalen'
#   - w104b: XML='Haſt' vs. JSON='Hast'
#   - w1082: XML='Ahl' vs. JSON='Ahl.'
#   - w10d1: XML='Carlſon' vs. JSON='Carlson'
#   - w10e8: XML='Åckermann' vs. JSON='Ackermann'
#   - w94a: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - wa82: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w1dba: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w5deb: XML='Koͤhler' vs. JSON='Köhler'
#   - w5f30: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w6454: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w647e: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w66b4: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w6fd4: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w80e0: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w8af7: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w8f8e: XML='Bonſin' vs. JSON='Bonsin'
#   - w8f90: XML='Su-' vs. JSON='Subokawa'
#   - w901b: XML='Oka-' vs. JSON='Okada'
#   - w901c: XML='Jeoſin' vs. JSON='Jeosin'
#   - w904e: XML='Kuriſuki' vs. JSON='Kurisuki'
#   - w9058: XML='Fokuſmoto' vs. JSON='Fokusmoto'
#   - w9059: XML='Doſin' vs. JSON='Dosin'
#   - w90b1: XML='Kat-' vs. JSON='Katfragawa'
#   - w9206: XML='Jonſtons' vs. JSON='Jonstons'
#   - w9225: XML='Heiſter' vs. JSON='Heister'
#   - w954a: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - wa06c: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - wc73a: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w103ee: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w1042d: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w10512: XML='Con-' vs. JSON='Confucius'
#   - w10d47: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w11182: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w111bb: XML='Tſu' vs. JSON='Tsu'
#   - w111c4: XML='Joſi' vs. JSON='Josi'
#   - w115e9: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w115f2: XML='Kinſeckwo' vs. JSON='Kinseckwo'
#   - w1162d: XML='Figaſi' vs. JSON='Figasi'
#   - w13dd6: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w163bc: XML='Dai-' vs. JSON='Daijojin'
#   - w1680c: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w17569: XML='Koſack' vs. JSON='Kosack'
#   - w18f3e: XML='Rader-' vs. JSON='Radermacher'
#   - w18fe3: XML='Ra-' vs. JSON='Radermacher'
#   - w19012: XML='Kaͤmpfer' vs. JSON='Kämpfer'
#   - w19084: XML='Stuͤtzer' vs. JSON='Stützer'
#   - w193da: XML='Boͤniken' vs. JSON='Böniken'
#   - w19476: XML='Boͤnikens' vs. JSON='Bönikens'
#   - w1b1a0: XML='Petterſen' vs. JSON='Pettersen'
#   - w1b484: XML='Sluyſken' vs. JSON='Sluysken'
#   - w1b48d: XML='Ka-' vs. JSON='Kaneel'
#   - w1b4d5: XML='Keu-' vs. JSON='Keulen'
#   - w1b4f6: XML='Hoͤpner' vs. JSON='Höpner'
#   - w1b6d5: XML='Sluyſken' vs. JSON='Sluysken'
#   - w1bb1e: XML='Sluyſken' vs. JSON='Sluysken'
#   - w1bcc2: XML='Wim-' vs. JSON='Wimmercranz'
#   - w1c0ca: XML='Sluyſken' vs. JSON='Sluysken'
#   - w1c7c1: XML='Ran-' vs. JSON='Ranzow'
#   - w1ca4c: XML='Wil-' vs. JSON='Wilhelm'
#   - w1fb04: XML='Jeſu' vs. JSON='Jesu'
#   - w1fb05: XML='Chriſti' vs. JSON='Christi'
#   - w1fb1c: XML='Jeſu' vs. JSON='Jesu'
#   - w1fb1d: XML='Chriſti' vs. JSON='Christi'
#   - w20a77: XML='Fehrſen' vs. JSON='Fehrsen'
#   - w20c99: XML='Paterſon' vs. JSON='Paterson'
#   - w214ca: XML='Beau-' vs. JSON='Beaumont'
#   - w21928: XML='Erſten' vs. JSON='Ersten'
#   - w219e4: XML='Haſſelgren' vs. JSON='Hasselgren'
#   - w219f7: XML='Faͤhraͤus' vs. JSON='Fähräus'
#   - w21ab2: XML='Solan-' vs. JSON='Solander'
#   - w21b86: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w21b99: XML='Kaͤmpfers' vs. JSON='Kämpfers'
#   - w21bfa: XML='Monſon' vs. JSON='Monson'
#   - w21c08: XML='Forſter' vs. JSON='Forster'
#   - w21c80: XML='So-' vs. JSON='Solander'
#   - w21cf5: XML='Cronſtedt' vs. JSON='Cronstedt'
#   - w13: XML='Upſala' vs. JSON='Upsala'
#   - w2a: XML='Aſien' vs. JSON='Asien'
#   - w45: XML='Stralſund' vs. JSON='Stralsund'
#   - w67: XML='Dezima' vs. JSON='Dezime'
#   - w7a: XML='Dezima' vs. JSON='Dezime'
#   - wa4: XML='Cap' vs. JSON='Kap'
#   - wa9: XML='Deutſchland' vs. JSON='Deutschland'
#   - w403: XML='Upſala' vs. JSON='Upsala'
#   - w4cd: XML='Vlißin-' vs. JSON='Vlißingen'
#   - w51f: XML='Koppenhagen' vs. JSON='Kopenhagen'
#   - w534: XML='Upſala' vs. JSON='Upsala'
#   - w588: XML='Stridsberg' vs. JSON='Stridesberg'
#   - weeb: XML='Upſala' vs. JSON='Upsala'
#   - w1263: XML='Africa' vs. JSON='Afrika'
#   - w1265: XML='Aſien' vs. JSON='Asien'
#   - w126e: XML='Aſien' vs. JSON='Asien'
#   - w12b7: XML='Banda' vs. JSON='Bande'
#   - w5d5: XML='Upſala' vs. JSON='Upsala'
#   - w1526: XML='Africa' vs. JSON='Afrika'
#   - w152c: XML='Africa' vs. JSON='Afrika'
#   - w5e3: XML='Drontheim' vs. JSON='Dronteheim'
#   - w609: XML='Upſala' vs. JSON='Upsala'
#   - w15c7: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w15cc: XML='Dezima' vs. JSON='Dezime'
#   - w656: XML='Formoſa' vs. JSON='Formosa'
#   - w66c: XML='Meaxima' vs. JSON='Maxima'
#   - w675: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w690: XML='Dezima' vs. JSON='Dezime'
#   - w767: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w76e: XML='Dezima' vs. JSON='Dezime'
#   - w7db: XML='Dezima' vs. JSON='Dezime'
#   - w82f: XML='Dezima' vs. JSON='Dezime'
#   - w15d3: XML='Dezima' vs. JSON='Dezime'
#   - w950: XML='Oriſſino' vs. JSON='Orissino'
#   - w95b: XML='Fiſen' vs. JSON='Fisen'
#   - w968: XML='Taiſero' vs. JSON='Taisero'
#   - w96b: XML='Tſikudſen' vs. JSON='Tsikudsen'
#   - w97c: XML='Koku-' vs. JSON='Kokura'
#   - w991: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w9ac: XML='Kaminoſeki' vs. JSON='Kaminoseki'
#   - w9c8: XML='Oſaka' vs. JSON='Osaka'
#   - w9d1: XML='Oſaka' vs. JSON='Osaka'
#   - w9d5: XML='Mia-' vs. JSON='Miako'
#   - w9f4: XML='Tſetta' vs. JSON='Zeta'
#   - wa16: XML='Mia' vs. JSON='Mia.'
#   - wa1f: XML='Okaſaki' vs. JSON='Okasaki'
#   - wa37: XML='Fuſikowa' vs. JSON='Fusikowa'
#   - wa3b: XML='Fuſi' vs. JSON='Fusi'
#   - wa63: XML='Totſka' vs. JSON='Totska'
#   - w15e5: XML='Dezima' vs. JSON='Dezime'
#   - wb68: XML='Fuſi' vs. JSON='Fusi'
#   - wbbb: XML='Oſaka' vs. JSON='Osaka'
#   - wbe7: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wbe9: XML='Dezima' vs. JSON='Dezime'
#   - w21d97: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w21d9d: XML='Dezima' vs. JSON='Dezime'
#   - w16a3: XML='Oſtindien' vs. JSON='Ostindien'
#   - w16e6: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w17b2: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w197c: XML='Canton' vs. JSON='Kanton'
#   - w1a5f: XML='Oſtindien' vs. JSON='Ostindien'
#   - w1bf5: XML='Formoſa' vs. JSON='Formosa'
#   - w1bfe: XML='Formo-' vs. JSON='Formosa'
#   - w1c59: XML='Formoſa' vs. JSON='Formosa'
#   - w1c62: XML='Formoſa' vs. JSON='Formosa'
#   - w1c65: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w1d90: XML='Formoſa' vs. JSON='Formosa'
#   - w1e88: XML='Meaxi-' vs. JSON='Maxima'
#   - w1ea4: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w1edd: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w1f8a: XML='Daͤnnemark' vs. JSON='Dänemark'
#   - w1f8c: XML='Deutſchland' vs. JSON='Deutschland'
#   - w213d: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w2144: XML='Dezima' vs. JSON='Dezime'
#   - w2237: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w22e5: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w23de: XML='Nan-' vs. JSON='Nagasaki'
#   - w2a76: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w2c0c: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w2c10: XML='Dezima' vs. JSON='Dezime'
#   - w2cc8: XML='Dezima' vs. JSON='Dezime'
#   - w2f06: XML='Dezima' vs. JSON='Dezime'
#   - w3523: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w35f5: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w3625: XML='Je-' vs. JSON='Jedo'
#   - w362c: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w3631: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w369c: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w37dd: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w37ff: XML='Dezima' vs. JSON='Dezime'
#   - w3c38: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w4072: XML='Fi-' vs. JSON='Fischer-Insel'
#   - w40ca: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w4246: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w427e: XML='Bata-' vs. JSON='Batavia'
#   - w46d0: XML='Indiſchen' vs. JSON='Indischen'
#   - w46d1: XML='Inſeln' vs. JSON='Inseln'
#   - w49fc: XML='Oſtindien' vs. JSON='Ostindien'
#   - w4c74: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w4e53: XML='Oſtindien' vs. JSON='Ostindien'
#   - w4e5d: XML='Ja-' vs. JSON='Japanischen'
#   - w4e5e: XML='Inſeln' vs. JSON='Inseln'
#   - w4f27: XML='Dezima' vs. JSON='Dezime'
#   - w4f2c: XML='Nan-' vs. JSON='Nagasaki'
#   - w52ea: XML='Canton' vs. JSON='Kanton'
#   - w5459: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w58b8: XML='Oſakka' vs. JSON='Osaka'
#   - w58ce: XML='Nanga-' vs. JSON='Nagasaki'
#   - w5ade: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w21dce: XML='Dezima' vs. JSON='Dezime'
#   - w5cc7: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w5cf8: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w5db0: XML='Dezima' vs. JSON='Dezime'
#   - w5e0c: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w623e: XML='Nanga-' vs. JSON='Nagasaki'
#   - w6324: XML='Iſafaga' vs. JSON='Isafaga'
#   - w642d: XML='Dezima' vs. JSON='Dezime'
#   - w6476: XML='Iſafaja' vs. JSON='Isafaja'
#   - w648a: XML='Si-' vs. JSON='Simabara'
#   - w649a: XML='Oriſſino' vs. JSON='Orissino'
#   - w64a7: XML='Otſinſu' vs. JSON='Otsinsu'
#   - w64aa: XML='Oriſſino' vs. JSON='Orissino'
#   - w6559: XML='Oſtindien' vs. JSON='Ostindien'
#   - w6599: XML='Fiſen' vs. JSON='Fisen'
#   - w662a: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w668c: XML='Kaſſanga' vs. JSON='Kassanga'
#   - w669a: XML='Fioſabara' vs. JSON='Fiosabara'
#   - w669c: XML='Kanſaki' vs. JSON='Kansaki'
#   - w66ab: XML='Taiſero' vs. JSON='Taisero'
#   - w6739: XML='Itſka' vs. JSON='Itska'
#   - w674f: XML='Farda' vs. JSON='Varda'
#   - w6790: XML='Utſini' vs. JSON='Utsini'
#   - w679a: XML='Tſikudſen' vs. JSON='Tsikudsen'
#   - w687b: XML='Utſini' vs. JSON='Utsini'
#   - w6886: XML='Koijanoſſa' vs. JSON='Koijanossa'
#   - w6888: XML='Kuroſakki' vs. JSON='Kurosakki'
#   - w69de: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w6a4c: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w6abe: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w6ac5: XML='Nipon' vs. JSON='Nippon'
#   - w6c22: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w6cf1: XML='Nakaſſima' vs. JSON='Nakassima'
#   - w6d13: XML='Kaminoſeki' vs. JSON='Kaminoseki'
#   - w6dc4: XML='Kaminoſeki' vs. JSON='Kaminoseki'
#   - w6dc7: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w6e32: XML='Dſino' vs. JSON='Dsino'
#   - w6ec9: XML='Materai' vs. JSON='Materei'
#   - w6f14: XML='Oſaka' vs. JSON='Osaka'
#   - w6fa3: XML='Oſaka' vs. JSON='Osaka'
#   - w6fb5: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w6fdf: XML='Oſaka' vs. JSON='Osaka'
#   - w6fe9: XML='Iſinomia' vs. JSON='Isinomia'
#   - w6feb: XML='Amagaſaki' vs. JSON='Amagasaki'
#   - w6ff5: XML='Kanſaki' vs. JSON='Kansaki'
#   - w700a: XML='Kanſaki' vs. JSON='Kansaki'
#   - w7019: XML='Oſaka' vs. JSON='Osaka'
#   - w7189: XML='Oſaka' vs. JSON='Osaka'
#   - w71ce: XML='Oſaka' vs. JSON='Osaka'
#   - w7345: XML='Oſaka' vs. JSON='Osaka'
#   - w739f: XML='Fuſimi' vs. JSON='Fusimi'
#   - w73a5: XML='Jodo' vs. JSON='Judo'
#   - w73ae: XML='Fiſimi' vs. JSON='Fisimi'
#   - w73c8: XML='Jodo' vs. JSON='Judo'
#   - w7535: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w7687: XML='Faſiri' vs. JSON='Fasiri'
#   - w7689: XML='Iſiba' vs. JSON='Isiba'
#   - w768d: XML='Tſetta' vs. JSON='Zeta'
#   - w7691: XML='Kuſats' vs. JSON='Kusats'
#   - w76f3: XML='Oſtindien' vs. JSON='Ostindien'
#   - w773d: XML='Kuſats' vs. JSON='Kusats'
#   - w774a: XML='Tſetta' vs. JSON='Zeta'
#   - w779c: XML='Iſſibe' vs. JSON='Issibe'
#   - w779e: XML='Naſumi' vs. JSON='Nasumi'
#   - w77a0: XML='Iſami' vs. JSON='Isami'
#   - w77a6: XML='Matſu' vs. JSON='Matsu'
#   - w77ad: XML='Sakanoſta' vs. JSON='Sakanosta'
#   - w77f8: XML='Iſi' vs. JSON='Isi'
#   - w7861: XML='Noſin' vs. JSON='Nosin'
#   - w7865: XML='Moirino-' vs. JSON='Moirinosta'
#   - w7869: XML='Tjakuſi' vs. JSON='Tjakusi'
#   - w7990: XML='Iſi' vs. JSON='Isi'
#   - w7ad8: XML='Kaſſadera' vs. JSON='Kassadera'
#   - w7ada: XML='Ma-' vs. JSON='Marumi'
#   - w7aeb: XML='Uſida' vs. JSON='Usida'
#   - w7af1: XML='Okaſaki' vs. JSON='Okasaki'
#   - w7af5: XML='Fuſikowa' vs. JSON='Fusikowa'
#   - w7af7: XML='Motoſiku' vs. JSON='Motosiku'
#   - w7af9: XML='Akaſaki' vs. JSON='Akasaki'
#   - w7afd: XML='Djokaſen' vs. JSON='Djokasen'
#   - w7aff: XML='Jootſia' vs. JSON='Jootsia'
#   - w7b01: XML='Joſida' vs. JSON='Josida'
#   - w7b09: XML='Okaſaki' vs. JSON='Okasaki'
#   - w7b98: XML='Jetſuri' vs. JSON='Jetsuri'
#   - w7b9a: XML='mura' vs. JSON='mure'
#   - w7b9c: XML='Siraſka' vs. JSON='Siraska'
#   - w7b9f: XML='Siraſka' vs. JSON='Siraska'
#   - w7c47: XML='Maiſaki' vs. JSON='Maisaki'
#   - w7c4b: XML='Si-' vs. JSON='Sinowara'
#   - w7c57: XML='Tinſjemmats' vs. JSON='Tinsjemmats'
#   - w7c63: XML='Daiſoin' vs. JSON='Daisoin'
#   - w7c65: XML='Mitſke' vs. JSON='Mitske'
#   - w7c71: XML='Fuku-' vs. JSON='Fukuroi'
#   - w7c82: XML='Niſſaka' vs. JSON='Nissaka'
#   - w7dda: XML='Cet-' vs. JSON='Getto'
#   - w7ddc: XML='Fuſida' vs. JSON='Fusida'
#   - w7dee: XML='Gurida-' vs. JSON='Guridama'
#   - w7e14: XML='Jeſero' vs. JSON='Jesero'
#   - w7e15: XML='no-' vs. JSON='nokaits'
#   - w7e19: XML='fraſawa' vs. JSON='frasawa'
#   - w7e22: XML='Fuſikowa' vs. JSON='Fusikowa'
#   - w7e27: XML='itſiban' vs. JSON='itsiban'
#   - w7e2a: XML='Sakki' vs. JSON='Sake'
#   - w7e2c: XML='Joſiwaro' vs. JSON='Josiwaro'
#   - w7e2e: XML='Kaſiwabara' vs. JSON='Kasiwabara'
#   - w7e34: XML='Nu-' vs. JSON='Numatso'
#   - w7e36: XML='Kiſigawa' vs. JSON='Kisigawa'
#   - w7e38: XML='Miſima' vs. JSON='Misima'
#   - w7e66: XML='Fuſikowa' vs. JSON='Fusikowa'
#   - w7e93: XML='Joſiwara' vs. JSON='Josiwara'
#   - w7e98: XML='Fuſi' vs. JSON='Fusi'
#   - w7fe3: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w829e: XML='Eu-' vs. JSON='Europa'
#   - w83c3: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w867f: XML='Fatta' vs. JSON='Fata'
#   - w8682: XML='batta' vs. JSON='Bata'
#   - w8686: XML='Kaſamats' vs. JSON='Kasamats'
#   - w86b3: XML='Sakkawa' vs. JSON='Sackkawa'
#   - w86c6: XML='Miſawa' vs. JSON='Misawa'
#   - w86c8: XML='Koſinkſif' vs. JSON='Kosinksif'
#   - w86ca: XML='Koiſo' vs. JSON='Koiso'
#   - w86cc: XML='Firaſka' vs. JSON='Firaska'
#   - w86da: XML='Fuſiſawa' vs. JSON='Fusisawa'
#   - w86e5: XML='Fukanoſikos' vs. JSON='Fukanosikos'
#   - w86e9: XML='Totſka' vs. JSON='Totska'
#   - w86f1: XML='Totſka' vs. JSON='Totska'
#   - w86f6: XML='Fuſiſawa' vs. JSON='Fusisawa'
#   - w873c: XML='Totſka' vs. JSON='Totska'
#   - w87a1: XML='Suru-' vs. JSON='Surumi'
#   - w87a3: XML='Kawaſakki' vs. JSON='Kawasakki'
#   - w87ab: XML='Obo-' vs. JSON='Obotoki'
#   - w8aaf: XML='Omu-' vs. JSON='Omura'
#   - w8ab1: XML='Fiſen' vs. JSON='Fisen'
#   - w8ab3: XML='Tſikungo' vs. JSON='Tsikungo'
#   - w8ab5: XML='Tſikudſen' vs. JSON='Tsikudsen'
#   - w8ab7: XML='Budſen' vs. JSON='Budsen'
#   - w8ab9: XML='Jammaſiwo' vs. JSON='Jammasiwo'
#   - w8abd: XML='Iſi' vs. JSON='Isi'
#   - w8ac9: XML='Muſafi' vs. JSON='Musafi'
#   - w8ad9: XML='Na-' vs. JSON='Nagatto'
#   - w8ae1: XML='Bitſju' vs. JSON='Bitsju'
#   - w8ae3: XML='Bidſen' vs. JSON='Bidsen'
#   - w8ae5: XML='Fari-' vs. JSON='Farima'
#   - w8ae7: XML='Sidſju' vs. JSON='Sidsju'
#   - w8b6e: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w918b: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w9949: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w9a73: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w9fa6: XML='Upſala' vs. JSON='Upsala'
#   - w21e23: XML='Dezima' vs. JSON='Dezime'
#   - wa34d: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wa37d: XML='Totſka' vs. JSON='Totska'
#   - wa3ea: XML='Upſala' vs. JSON='Upsala'
#   - wa469: XML='Miſima' vs. JSON='Misima'
#   - wa4c5: XML='Fuſi' vs. JSON='Fusi'
#   - wa4f0: XML='Niſſaka' vs. JSON='Nissaka'
#   - wabea: XML='Fuſimi' vs. JSON='Fusimi'
#   - wabfc: XML='Oſaka' vs. JSON='Osaka'
#   - wac0a: XML='Oſaka' vs. JSON='Osaka'
#   - wae57: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wae72: XML='Amſterdam' vs. JSON='Amsterdam'
#   - wb009: XML='Up-' vs. JSON='Upsala'
#   - wb2cd: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - wb382: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wb42b: XML='De-' vs. JSON='Dezime'
#   - wb47e: XML='Aſien' vs. JSON='Asien'
#   - wb4d7: XML='Nipon' vs. JSON='Nippon'
#   - wb4e2: XML='Japaniſchen' vs. JSON='Japanischen'
#   - wb4e3: XML='Inſeln' vs. JSON='Inseln'
#   - wb5f3: XML='Fuſi' vs. JSON='Fusi'
#   - wb715: XML='Dezima' vs. JSON='Dezime'
#   - wb717: XML='Nanga-' vs. JSON='Nagasaki'
#   - wb76f: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wb7ed: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wb855: XML='Dezima' vs. JSON='Dezime'
#   - wb8d9: XML='Simar' vs. JSON='Sima'
#   - wb8e9: XML='Simotſke' vs. JSON='Simotske'
#   - wb8ed: XML='Aſjo' vs. JSON='Asjo'
#   - wb8f3: XML='Chi-' vs. JSON='China'
#   - wb91c: XML='Cap' vs. JSON='Kap'
#   - wb935: XML='Upſala' vs. JSON='Upsala'
#   - wb978: XML='Tſugara' vs. JSON='Tsugara'
#   - wb9a5: XML='Booſa' vs. JSON='Boosa'
#   - wb9f2: XML='Sjoſuſima' vs. JSON='Sjosusima'
#   - wba2a: XML='Oſi' vs. JSON='Osi'
#   - wbae1: XML='Europa’s' vs. JSON='Europa's'
#   - wbe52: XML='Ja-' vs. JSON='Japaner'
#   - wc066: XML='Dezima' vs. JSON='Dezime'
#   - wc18a: XML='Ja-' vs. JSON='Japaner'
#   - wc614: XML='For-' vs. JSON='Formosa'
#   - wc6e4: XML='Formoſa' vs. JSON='Formosa'
#   - wc892: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wda2f: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - we449: XML='Nipon' vs. JSON='Nippon'
#   - we4cd: XML='Stock-' vs. JSON='Stockholm'
#   - we553: XML='Nipon' vs. JSON='Nippon'
#   - we5a7: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - we644: XML='Koſju' vs. JSON='Kosju'
#   - web2d: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - web47: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wf37f: XML='Dezima' vs. JSON='Dezime'
#   - wf5d9: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - wf691: XML='Nanga-' vs. JSON='Nagasaki'
#   - wf714: XML='Dſino' vs. JSON='Dsino'
#   - wf720: XML='Kaminoſeki' vs. JSON='Kaminoseki'
#   - wf794: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - wf7d8: XML='Si-' vs. JSON='Simonoseki'
#   - wf834: XML='Simonoſeki' vs. JSON='Simonoseki'
#   - w103ba: XML='Ja-' vs. JSON='Japan'
#   - w24779: XML='Ja-' vs. JSON='Japaner'
#   - w247b1: XML='Dezima' vs. JSON='Dezime'
#   - w107a4: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w107bd: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w108ef: XML='Ba-' vs. JSON='Batavia'
#   - w1095e: XML='Barbary' vs. JSON='Barbarei'
#   - w10bd3: XML='Trankebar' vs. JSON='Trankbar'
#   - w10c8d: XML='Cap' vs. JSON='Cap.'
#   - w10cb8: XML='Cap' vs. JSON='Cap.'
#   - w10cca: XML='Aſcenſionsinſel' vs. JSON='Ascensionsinsel'
#   - w10cd5: XML='Cap' vs. JSON='Kap'
#   - w10ceb: XML='Te-' vs. JSON='Texel'
#   - w10cfe: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w10d5b: XML='Suͤdſeeinſeln' vs. JSON='Südseeinseln'
#   - w10d68: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w10d6c: XML='Stralſund' vs. JSON='Stralsund'
#   - w10d6e: XML='Greifs-' vs. JSON='Greifswald'
#   - w10d72: XML='Yſtad' vs. JSON='Ystad'
#   - w10d79: XML='J' vs. JSON='Japan'
#   - w1100d: XML='Ja-' vs. JSON='Japan'
#   - w1168f: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w11cd5: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w12017: XML='Iſie' vs. JSON='Isie'
#   - w12171: XML='Iſie' vs. JSON='Isie'
#   - w1255d: XML='Oſtindiens' vs. JSON='Ostindiens'
#   - w12561: XML='Ma-' vs. JSON='Malabar'
#   - w12594: XML='Oſtindien' vs. JSON='Ostindien'
#   - w1259b: XML='Aſiens' vs. JSON='Asiens'
#   - w127ec: XML='Nan-' vs. JSON='Nangasacki'
#   - w12b2e: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w13170: XML='De-' vs. JSON='Dezime'
#   - w1328a: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w13767: XML='Ja-' vs. JSON='Japan'
#   - w13d15: XML='Ja-' vs. JSON='Japaner'
#   - w13da4: XML='Oſa-' vs. JSON='Osaka'
#   - w13da6: XML='Gangaſali' vs. JSON='Gangasali'
#   - w13f6b: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w13f6e: XML='Oſaka' vs. JSON='Osaka'
#   - w14157: XML='Iſie' vs. JSON='Isie'
#   - w146f4: XML='Formoſa' vs. JSON='Formosa'
#   - w15041: XML='Oſtindien' vs. JSON='Ostindien'
#   - w1579a: XML='Satſuma' vs. JSON='Satsuma'
#   - w159a4: XML='Nipon' vs. JSON='Nippon'
#   - w15adf: XML='Eu-' vs. JSON='Europa'
#   - w15b56: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w15c52: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w15ca3: XML='Dezima' vs. JSON='Dezime'
#   - w15e07: XML='Eu-' vs. JSON='Europa'
#   - w15e0c: XML='Oſtindien' vs. JSON='Ostindien'
#   - w16007: XML='Japaniſchen' vs. JSON='Japanischen'
#   - w16008: XML='Inſeln' vs. JSON='Inseln'
#   - w160ba: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w16147: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w1618b: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w162e8: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w163d2: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w165ac: XML='Ja-' vs. JSON='Japaner'
#   - w165f5: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w1661d: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w1752d: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w249cf: XML='Upſa-' vs. JSON='Upsala'
#   - w24a2c: XML='Nipon' vs. JSON='Nippon'
#   - w25093: XML='Nagaſaki' vs. JSON='Nagasaki'
#   - w2509c: XML='Nan-' vs. JSON='Nangasacki'
#   - w250a4: XML='Fiſeni' vs. JSON='Fiseni'
#   - w250a7: XML='ſiquiſeni' vs. JSON='siquiseni'
#   - w250aa: XML='Fiſen' vs. JSON='Fisen'
#   - w250ac: XML='Siquiſen' vs. JSON='Siquisen'
#   - w2540b: XML='Oſtindien' vs. JSON='Ostindien'
#   - w255e9: XML='Oſakka' vs. JSON='Osakka'
#   - w255f2: XML='Oſakki' vs. JSON='Osakki'
#   - w2563a: XML='Nagaſaki' vs. JSON='Nagasaki'
#   - w25643: XML='Nan-' vs. JSON='Nangasakki'
#   - w25679: XML='Fiſeni' vs. JSON='Fiseni'
#   - w2567b: XML='Siguiſeni' vs. JSON='Siguiseni'
#   - w2567e: XML='Fiſen' vs. JSON='Fisen'
#   - w25684: XML='Si-' vs. JSON='Siquisen'
#   - w2584b: XML='Oſaka' vs. JSON='Osaka'
#   - w25855: XML='Oſacka' vs. JSON='Osaka'
#   - w17cd7: XML='Nangaſacki' vs. JSON='Nangasacki'
#   - w185e7: XML='Satſuma' vs. JSON='Satsuma'
#   - w185f2: XML='Tſikungo' vs. JSON='Tsikungo'
#   - w185f7: XML='Amakuſa' vs. JSON='Amakusa'
#   - w18661: XML='Katta-' vs. JSON='Kattami'
#   - w18672: XML='Silber-' vs. JSON='Silberinseln'
#   - w18674: XML='Ginſima' vs. JSON='Ginsima'
#   - w18676: XML='Kinſima' vs. JSON='Kinsima'
#   - w186b9: XML='Atſingo' vs. JSON='Atsingo'
#   - w186d5: XML='Satſuma' vs. JSON='Satsuma'
#   - w18706: XML='Mimaſaka' vs. JSON='Mimasaka'
#   - w18708: XML='Bitſju' vs. JSON='Bitsju'
#   - w1870a: XML='Biſen' vs. JSON='Bisen'
#   - w1876f: XML='Satſuma' vs. JSON='Satsuma'
#   - w25882: XML='Dezima' vs. JSON='Dezime'
#   - w187da: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w18822: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w188e7: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w18b00: XML='Dezi-' vs. JSON='Dezime'
#   - w18b2f: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w18b74: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w18b84: XML='Nanga-' vs. JSON='Nagasaki'
#   - w18c01: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w18c1b: XML='Dezi-' vs. JSON='Dezime'
#   - w18c2b: XML='Nangaſaki' vs. JSON='Nagasaki'
#   - w18cd7: XML='Dezima' vs. JSON='Dezime'
#   - w18d41: XML='Cavallos' vs. JSON='Cavalos'
#   - w18e96: XML='Oſtindien' vs. JSON='Ostindien'
#   - w18ef4: XML='Ja-' vs. JSON='Japan'
#   - w1900a: XML='Bata-' vs. JSON='Batavia'
#   - w1907a: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w192cf: XML='Liſſa-' vs. JSON='Lissabon'
#   - w1944e: XML='Jua-' vs. JSON='Juana'
#   - w196cb: XML='Tun-' vs. JSON='Tundang'
#   - w199f5: XML='Koppin' vs. JSON='Chopin'
#   - w19a06: XML='Kopping' vs. JSON='Kopping.'
#   - w19a41: XML='Kopping' vs. JSON='Kopping.'
#   - w19a4f: XML='Kopping' vs. JSON='Kopping.'
#   - w19a97: XML='Kopping' vs. JSON='Kopping.'
#   - w19af4: XML='Koppin' vs. JSON='Koppin.'
#   - w19b12: XML='Salatiga' vs. JSON='Salatiga.'
#   - w19b35: XML='Unarang' vs. JSON='Unarang.'
#   - w19b48: XML='Koppin' vs. JSON='Chopin'
#   - w19cb9: XML='Kopping' vs. JSON='Kopping.'
#   - w19d7c: XML='Tundang' vs. JSON='Tundang.'
#   - w19e0b: XML='Sa-' vs. JSON='Samarang.'
#   - w19e30: XML='Sa-' vs. JSON='Salatiga'
#   - w1a5d4: XML='Tjiſerva' vs. JSON='Tjiserva'
#   - w1a790: XML='Tjiſeroa' vs. JSON='Tjiseroa'
#   - w1a793: XML='Pondo-' vs. JSON='Pondogede'
#   - w1ae74: XML='Bata-' vs. JSON='Batavia'
#   - w1b03d: XML='mo-' vs. JSON='moluckischen'
#   - w1b03e: XML='Inſeln' vs. JSON='Inseln'
#   - w1b058: XML='Canton' vs. JSON='Kanton'
#   - w1b258: XML='Schwe-' vs. JSON='Schweden'
#   - w1b2b0: XML='Cap' vs. JSON='Kap'
#   - w1b413: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w1b5db: XML='Ba-' vs. JSON='Batavia'
#   - w1b6c9: XML='Barbary' vs. JSON='Barbarei'
#   - w1b708: XML='Kaltere' vs. JSON='Kalter'
#   - w1b70a: XML='Barbary' vs. JSON='Barbarei'
#   - w1b807: XML='Kaltere' vs. JSON='Kalter'
#   - w1b819: XML='Barbary' vs. JSON='Barbarei'
#   - w1b908: XML='Matſure' vs. JSON='Mattsure'
#   - w1baa7: XML='Oſtindien' vs. JSON='Ostindien'
#   - w1bad4: XML='Eu-' vs. JSON='Europa'
#   - w1bb26: XML='Negum-' vs. JSON='Negumbo'
#   - w1bbe4: XML='Upſala' vs. JSON='Upsala'
#   - w1bced: XML='Eu-' vs. JSON='Europa'
#   - w1c31a: XML='Cap' vs. JSON='Kap'
#   - w1c325: XML='Cap' vs. JSON='Kap'
#   - w1c56a: XML='Vorgebir-' vs. JSON='Vorgebirges'
#   - w1c5ca: XML='Eu-' vs. JSON='Europa'
#   - w1c6dc: XML='Mala-' vs. JSON='Malabaren'
#   - w1c9a1: XML='Kaltere' vs. JSON='Kalter'
#   - w1c9a3: XML='Barbary' vs. JSON='Barbarei'
#   - w1cb3a: XML='Si-' vs. JSON='Siruwaka'
#   - w1ddda: XML='maldiviſchen' vs. JSON='maledivischen'
#   - w1dddb: XML='Inſeln' vs. JSON='Inseln'
#   - w1def2: XML='Jafna' vs. JSON='Jaffna'
#   - w1e150: XML='Co-' vs. JSON='Columbo'
#   - w1e1a8: XML='Jafna' vs. JSON='Jaffna'
#   - w1e509: XML='Cap' vs. JSON='Kap'
#   - w1ed39: XML='Oſtindien' vs. JSON='Ostindien'
#   - w1f411: XML='Co-' vs. JSON='Columbo'
#   - w1f7e3: XML='Adamsſpitze' vs. JSON='Adamsspitze'
#   - w1f88e: XML='Trankebar' vs. JSON='Trankbar'
#   - w1f8bf: XML='Trankebar' vs. JSON='Trankbar'
#   - w1f917: XML='Aſiens' vs. JSON='Asiens'
#   - w1f928: XML='Aſiens' vs. JSON='Asiens'
#   - w1facd: XML='Upſala' vs. JSON='Upsala'
#   - w1fb31: XML='Co-' vs. JSON='Colombo'
#   - w1fb76: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w1fdc7: XML='Kaſchi' vs. JSON='Kasche'
#   - w1ff3e: XML='Cap' vs. JSON='Kap'
#   - w200c0: XML='Oſtin-' vs. JSON='Ostindien'
#   - w20300: XML='Ma-' vs. JSON='Malabar'
#   - w20593: XML='Trankebar' vs. JSON='Trankbar'
#   - w205b3: XML='Mala-' vs. JSON='Malabar'
#   - w20665: XML='Cock' vs. JSON='Kok'
#   - w206a5: XML='Cap' vs. JSON='Kap'
#   - w206fd: XML='Cap' vs. JSON='Kap'
#   - w20700: XML='Robben-' vs. JSON='Robbeneiland'
#   - w20721: XML='Cap' vs. JSON='Kap'
#   - w2081e: XML='Vorgebuͤrge' vs. JSON='Vorgebürge'
#   - w209e6: XML='Robbeneyland' vs. JSON='Robbeneiland'
#   - w20a46: XML='Cap' vs. JSON='Kap'
#   - w20b7b: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w20b94: XML='Cap' vs. JSON='Kap'
#   - w20bd3: XML='Upſala' vs. JSON='Upsala'
#   - w20bdf: XML='In-' vs. JSON='Indien'
#   - w20be3: XML='Capſtadt' vs. JSON='Kapstadt'
#   - w20c42: XML='hottentottiſchhollaͤndiſchen' vs. JSON='hottentottischholländischen'
#   - w20d0b: XML='Oſt-' vs. JSON='Ostindien'
#   - w20d21: XML='Cap' vs. JSON='Kap'
#   - w20d2f: XML='Eu-' vs. JSON='Europa'
#   - w20d5c: XML='Cap' vs. JSON='Kap'
#   - w20fc6: XML='Oſt-' vs. JSON='Ostindien'
#   - w2102a: XML='Aſcenſion' vs. JSON='Ascension'
#   - w21043: XML='Cap' vs. JSON='Kap'
#   - w21231: XML='Cap' vs. JSON='Kap'
#   - w2124a: XML='Oſtindien' vs. JSON='Ostindien'
#   - w212d9: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w2139c: XML='Cap' vs. JSON='Kap'
#   - w215de: XML='Cap' vs. JSON='Kap'
#   - w215fe: XML='Cap' vs. JSON='Kap'
#   - w21626: XML='Cap' vs. JSON='Kap'
#   - w2167b: XML='Cap' vs. JSON='Kap'
#   - w216fa: XML='Cap' vs. JSON='Kap'
#   - w21744: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w21755: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w21809: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w218bb: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w218fb: XML='Eu-' vs. JSON='Europa'
#   - w219de: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w21d09: XML='Deutſchland' vs. JSON='Deutschland'
#   - w21d0b: XML='Yſtad' vs. JSON='Ystad'
#   - w21d1d: XML='Amſterdam' vs. JSON='Amsterdam'
#   - w21d31: XML='Groͤningen' vs. JSON='Gröningen'
#   - w21d41: XML='Luͤbeck' vs. JSON='Lübeck'
#   - w21d45: XML='Roſtock' vs. JSON='Rostock'
#   - w21d47: XML='Stralſund' vs. JSON='Stralsund'
#   - w21d54: XML='Stralſund' vs. JSON='Stralsund'
#   - w21d71: XML='Yſtad' vs. JSON='Ystad'

# %% [markdown]
# In ersten Versuchen zeigte sich schnell, dass sich in dem Texte zwei größere Abschnitte befinden, in denen japanische Übersetzungen vermerkt sind.
#
# Zusätzlich findet sich einer kürzerer Abschnitt mit japanischen Zahlwörtern und am Ende des Bandes wurde ein Korrekturliste von lateinsichen Pflanzennamen aus dem ersten Band angehängt.
#
# Diese Abschnitte werden unweigerlich zu Problemen führen und deshalb kurzerhand entfernt. Sie lassen sich im restlichen Textlayout auch leicht identifizieren, wie nachstehende Skriptausgabe zeigen soll.
#
# Im Detail handelt es sich um folgende Abschnitte:
#
# Satz 3090 - 5012
#
# Satz 6508 - 7071
#
# Satz 8320 - 8350
#
# Satz 8576 - 8611

# %%
import json

# Datei laden
input_file = "reisen02_tcf.json"

# JSON-Datei laden
with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# Alle sentence_ids und zugehörigen Texte ausgeben
for sentence in data["sentences"]:
    sentence_id = sentence["sentence_id"]
    norm_text = sentence["norm_sentence"]["text"]
    print(f"Sentence ID: {sentence_id}, Text: {norm_text}")
# Out:
# Sentence ID: 0, Text: Karl Peter Thunbergs, Ritters des Königlichen Schwedischen Wasaordens, Doktors der Arzneigelahrtheit, Professors der Botanik zu Upsala, und Mitgliedes verschiedener, einheimischer und auswärtiger Akademien und gelehrter Gesellschaften, Reise durch einen Teil von Europa, Afrika und Asien, hauptsächlich in Japan, in den Jahren 1770 bis 1779.
# Sentence ID: 1, Text: Aus dem Schwedischen frei übersetzt von Christian Heinrich Groskurd, Rektor des Gymnasiums zu Stralsund.
# Sentence ID: 2, Text: Mit Kupfern.
# Sentence ID: 3, Text: Zweiter Band.
# Sentence ID: 4, Text: Berlin bei Haude und Spener, 1794.
# Sentence ID: 5, Text: Vorrede des Verfassers.
# Sentence ID: 6, Text: Dieser zweite Band meiner Reisebeschreibung enthält die Reise von Batavia nach Japan, den Aufenthalt auf der Insel Dezime, die Reise nach Jedo, der Hauptstadt von Japan, den Aufenthalt daselbst, die Rückreise nach Dezime, mannigfaltige Nachrichten von diesem Lande und dessen Einwohnern; Ferner meine Rückreise nach Batavia, Nachrichten von Java, die Reise nach Ceylon, einige Reisen längs den Küsten dieser Insel, Nachrichten von Ceylon, und meine Zurückreise über Kap durch Holland, England Deutschland nach Schweden.
# Sentence ID: 7, Text: Auch diesem Bande habe ich einige Abbildungen, und zwar von verschiedenen japanischen Gegenständen, beigefügt.
# Sentence ID: 8, Text: Japan, von welchem in diesem Bande vorzüglich die Rede ist, ist, in Vergleichung mit anderen europäischen Ländern, in vielen Rücksichten ein ganz besonderes Land!
# Sentence ID: 9, Text: Die Regierungsverfassung ist dort seit sehr langer Zeit unverändert dieselbe; die Gesetze sind strenge und unwandelbar; die Polizei in Städten, Dörfern und auf den Landstraßen ist unverbesserlich; die Kleidertracht, Putz und Art das Haar zu tragen ist durchaus gleichförmig und, so wie die Sitten, Gewohnheiten und Gebräuche, seit Jahrhunderten unverändert; eine unzählige Menge von Einwohnern lebt dort ohne Parteien, ohne Zwiespalt und Uneinigkeit, ohne Missvergnügen, Elend und Auswanderung; der Ackerbau ist im blühendsten Zustande; die Erde gebaut und benutzt wie in keinem anderen Lande der Welt; alle Bedürfnisse sind, im Lande selbst, in solchem Überfluß vorhanden daß kein auswärtiger Handel nötig ist; doch fast möchte ich sagen: wer kann die Vorzüge und Vorteile dieses glücklichen Landes alle zählen? --
# Sentence ID: 110, Text: 52. Museum naturale academiae Upsaliensis, P. XI. Resp. Sjöberg 1792.
# Sentence ID: 111, Text: 53. -- -- -- -- P. XII. Resp. Lindbladh 1792.
# Sentence ID: 112, Text: 54 -- -- -- -- P. XIII. Resp. Feretius 1792.
# Sentence ID: 113, Text: An Sozietäten der Wissenschaften habe ich folgende Abhandlungen, über verschiedene Gegenstände, eingesandt:
# Sentence ID: 114, Text: An die Akademie der Wissenschaften zu Stockholm.
# Sentence ID: 115, Text: 1. Händelse, as Blyhvit af förseende blifvit brukadt i matt ( Vorfall, da Bleiweiß durch ein Versehen ans Essen gebraucht worden ), 1773. 1 Quartal, S. 29.
# Sentence ID: 116, Text: 2. Beskrifning pa en besynnertig auch obekant Svamp, Hydnora Africana.
# Sentence ID: 117, Text: ( Beschreibung eines besonderen und unbekannten Schwamms, Hydnora Africana ), 1775. 1 Qu. S. 69. 1 Kupfertafel.
# Sentence ID: 118, Text: 3. Beskrifning pa et nett Genus i bland Jnsecterne, Pneumora.
# Sentence ID: 119, Text: ( Beschreibung eines neuen Geschlechts von Insekten, Pneumore ), 1775. 3 Qu. S. 254. 1 K. T.
# Sentence ID: 120, Text: 4. Rothmannia, et nytt Örte-Genus.
# Sentence ID: 121, Text: ( Die Rothmannie, ein neues Pflanzengeschlecht 1776 ), 1 Qu. S. 65. 1 K. T.
# Sentence ID: 122, Text: 5. Beskrifning pa et nytt Örte-Genus kalladt Radermachia.
# Sentence ID: 123, Text: ( Beschreibung eines neuen Pflanzengeschlechts, Radermachie genannt ), 1776. 3 Qu. S. 250.
# Sentence ID: 124, Text: 6. Anmärkningar vid Hydnora africana.
# Sentence ID: 125, Text: ( Anmerkungen zur afrikanischen Hydnore ), 1777. 2 Qu. S. 144. 1 K. T.
# Sentence ID: 126, Text: 7.
# Sentence ID: 127, Text: Beskrifning pa en Bezoar Equinum.
# Sentence ID: 128, Text: ( Beschreibung eines Pferdebezoarsteins ), 1778. 1 Qu. S. 27.
# Sentence ID: 129, Text: 8. Et nytt auch Til Sitt slägte för obekant Grüs, kalladt Ehrhardta.
# Sentence ID: 130, Text: ( Eine neue und in Ansehung ihres Geschlechts bisher unbekannte Grasart, Ehrharte genannt ), 1779. 3 Qu. S. 216. 1 K. T.
# Sentence ID: 131, Text: 9. Anmärkningar vid Canelen, gjorde pa Ceilon.
# Sentence ID: 132, Text: ( Bemerkungen über den Kaneel, auf Ceilon gemacht. ) 1770 1 Qu. S. 55. übersetzt und in die Abhandlungen der vlißingschen Sozietät der Wissenschaften, 12 Th. 1 Adth. S. 296., eingerückt von Doktor Houtuyn.
# Sentence ID: 133, Text: 10. Beskrifning pa Weigelia Japonica, en sälsynt örl fran Japan.
# Sentence ID: 134, Text: ( Beschreibung der japanischen Weigelie, eines seltenen Gewächses aus Japan ) 1780. 2 Qu. S. 137.
# Sentence ID: 135, Text: 11. Beskrifning pa nagra varme Bäten i Afrika auch Asien ( Beschreibung einiger warmen Bäder in Afrika und Asien. ) 1781. 1 Qu. S. 72.
# Sentence ID: 136, Text: 12. Beskrifning pa tvänne nya Jnsecter.
# Sentence ID: 8590, Text: 124. -- 1. -- Fulices lies Fulicae. --
# Sentence ID: 8591, Text: 168. -- 3. -- tygomaticum lies zygomaticum. --
# Sentence ID: 8592, Text: 191. -- 26. -- Unicornum lies Unicornu. --
# Sentence ID: 8593, Text: 246. -- 12. -- mais lies Mays. --
# Sentence ID: 8594, Text: 258. -- 23. -- Nila lies Anil.
# Sentence ID: 8595, Text: Zweiter Band.
# Sentence ID: 8596, Text: Erster Theil. pag. 41. Zeile 30. statt virens lies sempervirens. --
# Sentence ID: 8597, Text: 123. -- 5. -- bastatum lies hastatum. --
# Sentence ID: 8598, Text: 123. -- 26. -- Licium lies Lycium.
# Sentence ID: 8599, Text: Zweiten Bandes.
# Sentence ID: 8600, Text: Zweiter Theil. pag. 65. Zeile 29. statt panium lies Panicum. --
# Sentence ID: 8601, Text: 66 -- 7. -- Satirus -- sativus. --
# Sentence ID: 8602, Text: 66 -- 31. -- Punicum lies Punica. --
# Sentence ID: 8603, Text: 67. -- 10. -- Mioya lies Mioga. --
# Sentence ID: 8604, Text: 87. -- 21. -- Azedarach, Melia lies Melia Azedaraen -- 113. -- 18. -- sirofa lies fcrofa. --
# Sentence ID: 8605, Text: 114. -- 17. -- pyrrhyla lies Pyrrhula. --
# Sentence ID: 8606, Text: 115. -- 2. -- Ophichthys lies Ophichthus. --
# Sentence ID: 8607, Text: 115. -- 10. -- Fistelarie lies Fistularia. --
# Sentence ID: 8608, Text: 115. -- 30. -- Melve lies Meloe. --
# Sentence ID: 8609, Text: 117. -- 16. -- Onisius lies Oniscus. --
# Sentence ID: 8610, Text: 120. -- 1. -- cannena lies Canrena. --
# Sentence ID: 8611, Text: 204. -- 12. -- Melange lies Melongena.

# %% [markdown]
# Folgender Code-Block entfernt die entsprechenden Abschnitte:
# 3090 bis 5012
# 6508 bis 7071
# 8320 bis 8350
# 8576 bis 8611

# %%
import json

# Datei laden
input_file = "reisen02_tcf.json"
output_file = "reisen02_filtered.json"

# ID-Ranges angeben
id_ranges = [
    range(3090, 5013),
    range(6508, 7072),
    range(8320, 8351),
    range(8576, 8612)
]

# JSON-Datei laden
with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# Sätze filtern
filtered_sentences = []
for sentence in data["sentences"]:
    sentence_id = sentence["sentence_id"]
    # Prüfen, ob die sentence_id in einem der Ranges liegt
    if not any(sentence_id in id_range for id_range in id_ranges):
        filtered_sentences.append(sentence)

# Gefilterte Daten speichern
data["sentences"] = filtered_sentences
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Die Sätze in den angegebenen Bereichen wurden entfernt. Gefilterte Datei: {output_file}")
# Out:
# Die Sätze in den angegebenen Bereichen wurden entfernt. Gefilterte Datei: reisen02_filtered.json

# %% [markdown]
# Die nun vorhandene `reisen02_filtered.json` kann für die Textnormalisierung und Informationsextraktion mit gemma3 genutzt werden.

# %%
import json

# Datei laden
input_file = "reisen02_filtered.json"

# JSON-Datei laden
with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# Alle sentence_ids und zugehörigen Texte ausgeben
for sentence in data["sentences"]:
    sentence_id = sentence["sentence_id"]
    norm_text = sentence["norm_sentence"]["text"]
    print(f"Sentence ID: {sentence_id}, Text: {norm_text}")
